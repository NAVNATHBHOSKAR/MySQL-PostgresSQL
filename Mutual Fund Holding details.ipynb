# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install PrettyTable
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def Quant_Info():
  print("\t\t Quant Tax Plan Direct-Growth \n")
  print("--------------------------------------------------------- ")
  print("			 Fund Information											")
  print("--------------------------------------------------------- ")
  print(" Fund Type: Open-End       	 Plan: Growth ")
  print(" Scheme Size: 1358.81 Cr    	 Expense Ratio:0.57 ")
  print(" Cash Holding: 1.23%       	 As on Date:31 May 2022 ")
  print(" Exit Load:No charges on withdrawl ")

def Axis_Info():
  print("\t\t Axis Long Term Equity Direct Plan-Growth \n")
  print("--------------------------------------------------------- ")
  print("			 Fund Information											")
  print("--------------------------------------------------------- ")
  print(" Fund Type: Open-End       	 Plan: Growth ")
  print(" Scheme Size: 29583.87 Cr     Expense Ratio:0.77 ")
  print(" Cash Holding: -0.02%       	 As on Date:31 May 2022 ")
  print(" Exit Load:No charges on withdrawl ")

def Quant_Details():
  Units = 51.587
  Avg_Purchase_NAV = 203.5397
  print("Units:-",Units)
  print("Avg. Purchase NAV ₹",Avg_Purchase_NAV)

def Axis_Details():
  Units = 143.994
  Avg_Purchase_NAV = 72.9197
  print("Units:-",Units)
  print("Avg. Purchase NAV ₹",Avg_Purchase_NAV)

def Quant_Transactions():
  from prettytable import PrettyTable
  Quant = PrettyTable()
  Quant.field_names = ['Amount','Investment Type','NAV Price','Units','NAV Date']
  Quant.add_row([500,'SIP',237.8598,2.102,'24 Jul 2022'])
  Quant.add_row([500,'SIP',217.5692,2.298,'24 Jun 2022'])
  Quant.add_row([500,'SIP',228.7131,2.186,'24 May 2022'])
  Quant.add_row([500,'SIP',244.9920,2.041,'25 Apr 2022'])
  Quant.add_row([500,'SIP',217.4073,2.300,'8 Mar 2022'])
  Quant.add_row([500,'SIP',213.1750,2.345,'24 Feb 2022'])
  Quant.add_row([500,'Lumpsum',237.6746,2.104,'15 Feb 2022'])
  Quant.add_row([500,'SIP',231.7761,2.157,'24 Jan 2022'])
  Quant.add_row([500,'Lumpsum',233.2965,2.143,'27 Dec 2021'])
  Quant.add_row([500,'SIP',239.3373,2.089,'24 Nov 2021'])
  Quant.add_row([500,'SIP',242.0053,2.066,'17 Nov 2021'])
  Quant.add_row([500,'SIP',232.4872,2.151,'25 Oct 2021'])
  Quant.add_row([500,'Lumpsum',238.2115,2.099,'20 Oct 2021'])
  Quant.add_row([500,'SIP',227.7731,2.195,'24 Sep 2021'])
  Quant.add_row([500,'SIP',217.1145,2.303,'27 Jul 2021'])
  Quant.add_row([500,'SIP',205.6167,2.432,'30 Jun 2021'])
  Quant.add_row([500,'Lumpsum',201.5054,2.481,'04 Jun 2021'])
  Quant.add_row([500,'SIP',174.3931,2.867,'22 Apr 2021'])
  Quant.add_row([500,'Lumpsum',163.6462,3.055,'08 Mar 2021'])
  Quant.add_row([500,'Lumpsum',156.9075,3.186,'12 Feb 2021'])
  Quant.add_row([500,'SIP',148.8651,3.359,'07 Jan 2021'])
  Quant.add_row([500,'SIP',134.0355,3.730,'02 Dec 2021'])

  print(Quant)


def Axis_Transactions():
  from prettytable import PrettyTable
  Axis = PrettyTable()
  Axis.field_names = ['Amount','Investment Type','NAV Price','Units','NAV Date']
  Axis.add_row([500,'SIP',69.7673,7.166,'24 Jul 2022'])
  Axis.add_row([500,'SIP',65.2431,7.663,'24 Jun 2022'])
  Axis.add_row([500,'SIP',66.3628,7.534,'24 May 2022'])
  Axis.add_row([500,'SIP',74.1743,6.741,'25 Apr 2022'])
  Axis.add_row([500,'SIP',70.6214,7.080,'8 Mar 2022'])
  Axis.add_row([500,'SIP',71.3778,7.005,'24 Feb 2022'])
  Axis.add_row([500,'Lumpsum',76.0554,6.574,'15 Feb 2022'])
  Axis.add_row([500,'SIP',76.6805,6.520,'24 Jan 2022'])
  Axis.add_row([500,'SIP',79.5375,6.286,'27 Dec 2021'])
  Axis.add_row([500,'SIP',82.3818,6.069,'24 Nov 2021'])
  Axis.add_row([500,'Lumpsum',85.3839,5.856,'17 Nov 2021'])
  Axis.add_row([500,'SIP',82.4621,6.063,'25 Oct 2021'])
  Axis.add_row([500,'Lumpsum',84.8923,5.890,'20 Oct 2021'])
  Axis.add_row([500,'SIP',84.7660,5.898,'24 Sep 2021'])
  Axis.add_row([500,'SIP',74.2940,6.730,'27 Jul 2021'])
  Axis.add_row([500,'Lumpsum',72.8723,6.861,'30 Jun 2021'])
  print(Axis)


def Quant_Holding_Summary():
  Scheme_Asset_Size=1358.81
  print("Scheme Asset Size =",Scheme_Asset_Size,"Cr.")
  print("As on date = 31 May 2022")

  import plotly.graph_objects as go
  labels = ['Services','Financial','Consumer Staples','Healthcare','Materials','Others']
  values = [22.05,15.94,12.25,10.14,10.01,29.60]
  fig = go.Figure(data=[go.Pie(labels=labels, values=values)])
  fig.show()


def Axis_Holding_Summary():
  Scheme_Asset_Size=1358.81
  print("Scheme Asset Size =",Scheme_Asset_Size,"Cr.")
  print("As on date = 31 May 2022")

  import plotly.graph_objects as go
  labels = ['Services','Financial','Technology','Healthcare','Chemicals','Others']
  values = [16.13,33.35,11.81,7.61,7.96,23.14]
  fig = go.Figure(data=[go.Pie(labels=labels, values=values)])
  fig.show()

# %%
def Fund_Information():
  print("\t\t\t 1) Quant Tax Plan Direct-Growth\n")
  print("\t\t\t 2) Axis Long Term Equity Direct Plan-Growth\n")
  
  ch=int(input("Choose an option:\n"))
  if ch == 1:
    Quant_Info()
    print("")
    n=int(input("0-BACK\n ->"))
    if n==0:
      Nava_Services()
	
  elif ch == 2:
    Axis_Info()
    print("")
    n=int(input("0-BACK\n ->"))
    if n==0:
      Nava_Services()
    
  else:
    exit()
  
def Advanced_Details():
  print("\t\t\t 1) Quant Tax Plan Direct-Growth\n")
  print("\t\t\t 2) Axis Long Term Equity Direct Plan-Growth\n")
  
  ch=int(input("Choose an option:\n"))
  if ch == 1:
    print("Quant Tax Plan Direct-Growth")
    Quant_Details()
	
  elif ch == 2:
    print("Axis Long Term Equity Direct Plan-Growth")
    Axis_Details()
	
  else:
    exit()
    
def My_Transactions():
  print("\t\t\t 1) Quant Tax Plan Direct-Growth\n")
  print("\t\t\t 2) Axis Long Term Equity Direct Plan-Growth\n")
  
  ch=int(input("Choose an option:\n"))
  if ch == 1:
    print("Quant Tax Plan Direct-Growth")
    print("My Transactions")
    Quant_Transactions()
	
  elif ch == 2:
    print("Axis Long Term Equity Direct Plan-Growth")
    Axis_Transactions()
	
  else:
    exit()

def Scheme_Holding_Summary():
  print("\t\t\t 1) Quant Tax Plan Direct-Growth\n")
  print("\t\t\t 2) Axis Long Term Equity Direct Plan-Growth\n")
  
  ch=int(input("Choose an option:\n"))
  if ch == 1:
    print("Quant Tax Plan Direct-Growth")
    #print("My Transactions")
    Quant_Holding_Summary()
	
  elif ch == 2:
    print("Axis Long Term Equity Direct Plan-Growth")
    Axis_Holding_Summary()
	
  else:
    exit()

# %%
def Nava_Services():
	print("\t\t\t\t\t\t Welcome to Nava Services\n")
	print("\t\t\t 1) Fund Information\n") #Booking
	print("\t\t\t 2) Advanced Details\n") #Rooms Info
	print("\t\t\t 3) My Transactions\n") #Room Service(Menu Card)
	print("\t\t\t 4) Scheme Holding Summary\n")#Payment
	print("\t\t\t 5) Cash Holding\n") #Record
	print("\t\t\t 0) Exit\n")
 
Nava_Services()
ch=int(input("Choose an option:\n"))
if ch == 1:
	print("")
	Fund_Information()
	
elif ch == 2:
	print("")
	Advanced_Details()
	
elif ch == 3:
  print("")
  My_Transactions()

elif ch == 4:
  print("Scheme Holding Summary")
  Scheme_Holding_Summary()
		
	
elif ch == 5:
	print("1.23%")
		#Record()

else:
	exit()
# Out:
# 						 Welcome to Nava Services
#
# 			 1) Fund Information
#
# 			 2) Advanced Details
#
# 			 3) My Transactions
#
# 			 4) Scheme Holding Summary
#
# 			 5) Cash Holding
#
# 			 0) Exit
#
# Choose an option:
# 3
#
# 			 1) Quant Tax Plan Direct-Growth
#
# 			 2) Axis Long Term Equity Direct Plan-Growth
#
# Choose an option:
# 2
# Axis Long Term Equity Direct Plan-Growth
# +--------+-----------------+-----------+-------+-------------+
# | Amount | Investment Type | NAV Price | Units |   NAV Date  |
# +--------+-----------------+-----------+-------+-------------+
# |  500   |       SIP       |  69.7673  | 7.166 | 24 Jul 2022 |
# |  500   |       SIP       |  65.2431  | 7.663 | 24 Jun 2022 |
# |  500   |       SIP       |  66.3628  | 7.534 | 24 May 2022 |
# |  500   |       SIP       |  74.1743  | 6.741 | 25 Apr 2022 |
# |  500   |       SIP       |  70.6214  |  7.08 |  8 Mar 2022 |
# |  500   |       SIP       |  71.3778  | 7.005 | 24 Feb 2022 |
# ...
